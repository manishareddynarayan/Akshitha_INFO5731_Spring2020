# %% [markdown]
# <a href="https://colab.research.google.com/github/akshithamaddi/Akshitha_INFO5731_Spring2020/blob/master/Copy_of_In_class_exercise_05_(7).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **The fifth in-class-exercise**

# %% [markdown]
# ## **1. Rule-based information extraction**
#
# Use any keywords related to data science, natural language processing, machine learning to search from google scholar, get the **titles** of 100 articles (either by web scraping or manually) about this topic, define a set of patterns to extract the research questions/problems, methods/algorithms/models, datasets, applications, or any other important information about this topic.

# %%
import re 
import string 
import nltk 
import spacy 
import pandas as pd 
import numpy as np 
import math 
from tqdm import tqdm 

from spacy.matcher import Matcher 
from spacy.tokens import Span 
from spacy import displacy 

pd.set_option('display.max_colwidth', 200)
# load spaCy model
nlp = spacy.load("en_core_web_sm")

# %%
text = open('100_titles.txt').read() 
doc = nlp(text)
for tok in doc: 
  print(tok.text, "-->",tok.dep_,"-->", tok.pos_)
# Out:
# Introduction --> ROOT --> NOUN
# to --> aux --> PART
# machine --> acl --> VERB
# learning --> xcomp --> NOUN
#
#  -->  --> SPACE
# Machine --> dobj --> NOUN
# learning --> acl --> NOUN
# : --> punct --> PUNCT
# a --> det --> DET
# probabilistic --> amod --> ADJ
# perspective --> nmod --> NOUN
#
#  -->  --> SPACE
# Machine --> appos --> NOUN
# learning --> acl --> NOUN
#
#  -->  --> SPACE
# Machine --> dobj --> NOUN
# learning --> xcomp --> NOUN
# : --> punct --> PUNCT
# an --> det --> DET
# algorithmic --> compound --> ADJ
# perspective --> pobj --> NOUN
#
#  -->  --> SPACE
# Foundations --> appos --> NOUN
# of --> prep --> ADP
# machine --> pobj --> NOUN
# learning --> acl --> VERB
#
#  -->  --> SPACE
# Machine --> dobj --> NOUN
# learning --> acl --> VERB
#
#  -->  --> SPACE
# Genetic --> amod --> ADJ
# algorithms --> nmod --> NOUN
# and --> cc --> CCONJ
# machine --> npadvmod --> NOUN
# learning --> conj --> VERB
#
#  -->  --> SPACE
# C4 --> dobj --> NOUN
# . --> punct --> PUNCT
# ...

# %%
import spacy
nlp = spacy.load('en_core_web_sm')
from spacy.matcher import Matcher
m_tool = Matcher(nlp.vocab) 
pattern = [{'POS':'ADJ'},  
           {'LOWER': 'methods'},
            {'POS':'ADP'},
            {'POS': 'NOUN'},
            {'POS': 'VERB'}
           ]  
pattern1 = [{'DEP':'amod', 'OP':"?"},
            {'POS':'ADJ'},  
           {'LOWER': 'methods'},
            {'POS':'ADP'},
            {'POS': 'NOUN'},
            {'POS': 'NOUN'},
            {'LOWER': 'and', 'OP':"?"}, 
           {'LOWER': 'or', 'OP':"?"}, 
            {'POS': 'NOUN'},
            {'POS': 'NOUN'}
           ]                                
pattern2 = [{'POS':'PROPN'},  
           {'LOWER': 'methods'},
            {'POS':'ADP'},
            {'POS': 'NOUN'},
            {'POS': 'VERB'}
           ]  
pattern3 = [{'POS':'PROPN'},  
           {'LOWER': 'methods'},
            {'POS':'ADP'},
            {'POS': 'ADJ'},
            {'IS_PUNCT': True},
            {'POS': 'NOUN'},
            {'POS': 'NOUN'},
            {'POS': 'NOUN'}
            ]
pattern4 = [{'DEP':'amod', 'OP':"?"},
            {'POS':'ADJ'},  
            {'POS': 'NOUN'},
            {'POS': 'NOUN'},
            {'IS_PUNCT': True},
            {'LOWER': 'methods'},
            {'LOWER': 'and', 'OP':"?"},
            {'POS': 'NOUN'}
            ]
pattern5 = [{'POS':'NOUN'},  
           {'IS_PUNCT': True},
            {'POS':'VERB'},
            {'POS': 'NOUN'}
           ]  
pattern6 = [{'POS':'VERB'},  
            {'POS':'VERB'},
            {'POS': 'NOUN'},
            {'POS':'VERB'},
            {'POS':'ADJ'},
            {'IS_PUNCT': True}
           ] 
pattern7 = [{'POS':'ADV'},  
            {'POS':'ADV'},
            {'IS_PUNCT': True},
            {'IS_PUNCT': True},
            {'POS': 'NOUN'},
            {'POS': 'NOUN'},
            {'POS':'VERB'},
            {'POS': 'NOUN'},
            {'POS': 'NOUN'},
            {'POS': 'NOUN'}
           ]   
pattern8 = [{'DEP':'amod', 'OP':"?"},
           {'POS':'ADJ'},  
           {'LOWER': 'algorithms'},
             {'LOWER': 'and', 'OP':"?"}, 
           {'LOWER': 'or', 'OP':"?"}, 
            {'POS': 'NOUN'},
            {'POS': 'VERB'}
           ]
pattern9 = [{'POS': 'NOUN'},
            {'POS': 'NOUN'},
            {'POS': 'NOUN'},
            {'IS_PUNCT': True},
            {'POS':'ADP'},
            {'POS': 'NOUN'},
            {'POS': 'ADP'},
            {'POS': 'VERB'}
           ]  
pattern10 = [{'POS': 'ADJ'},
            {'POS': 'NOUN'},
            {'POS': 'NOUN'},
            {'POS':'ADP'},
            {'POS': 'NOUN'},
            {'POS': 'VERB'},
            {'POS': 'NOUN'}
           ]
pattern11 = [{'DEP':'amod', 'OP':"?"},
             {'POS': 'ADJ'},
            {'POS': 'NOUN'},
            {'POS': 'ADP'},
            {'POS':'NOUN'},
            {'POS': 'NOUN'},
             {'LOWER': 'and', 'OP':"?"},
            {'POS': 'ADJ'},
            {'POS': 'NOUN'}
           ]
pattern12 = [{'POS': 'NOUN'},
            {'POS': 'VERB'},
            {'POS':'ADP'},
            {'POS': 'NOUN'},
            {'POS': 'VERB'}
           ] 
pattern13 = [{'POS': 'PROPN'},
            {'POS': 'NOUN'},
             {'IS_PUNCT': True},
            {'POS':'ADJ'},
            {'POS': 'NOUN'},
             {'POS': 'NOUN'},
             {'POS': 'NOUN'},
             {'LOWER': 'and', 'OP':"?"},
             {'POS': 'NOUN'},
             {'POS': 'ADP'},
             {'POS': 'PROPN'},
            {'POS': 'NOUN'}
           ]
pattern14 = [{'POS': 'PROPN'},
            {'POS': 'NOUN'},
            {'POS':'ADP'},
            {'POS': 'NOUN'},
            {'POS': 'NOUN'}
           ]
pattern15 = [{'POS': 'NOUN'},
            {'POS': 'NOUN'},
            {'LOWER': 'and', 'OP':"?"},
            {'POS': 'NOUN'},
            {'POS': 'NOUN'}
           ]
pattern16 = [{'POS': 'PROPN'},
            {'POS': 'VERB'},
             {'POS':'ADP'},
             {'IS_PUNCT': True},
             {'POS':'ADJ'},
            {'POS': 'NOUN'},
            {'POS': 'NOUN'},
            {'DEP':'nummod','OP':"?"} 
           ]
pattern17 = [{'POS': 'VERB'},
            {'POS': 'DET'},
             {'POS':'ADJ'},
             {'IS_PUNCT': True},
             {'POS':'ADJ'},
            {'POS': 'NOUN'},
             {'IS_PUNCT': True},
            {'POS': 'NOUN'},
             {'POS': 'NOUN'},
             {'IS_PUNCT': True},
             {'LOWER': 'and', 'OP':"?"},
            {'POS':'ADJ'},
             {'POS': 'NOUN'}
           ]
pattern20 = [{'POS': 'PROPN'},
            {'POS': 'ADP'},
            {'POS': 'NOUN'},
             {'POS': 'NOUN'},
             {'LOWER': 'and', 'OP':"?"},
            {'POS': 'NOUN'},
             {'POS': 'NOUN'}
           ]
pattern21 = [{'POS': 'ADJ'},
            {'POS': 'NOUN'},
             {'POS': 'NOUN'},
             {'IS_PUNCT': True},
             {'POS': 'NOUN'},
             {'LOWER': 'and', 'OP':"?"},
             {'POS': 'NOUN'}
           ]
pattern22 = [{'POS': 'NOUN'},
            {'POS': 'VERB'},
             {'POS': 'NOUN'},
             {'POS': 'ADP'},
             {'POS': 'NOUN'},
             {'LOWER': 'and', 'OP':"?"},
             {'POS': 'NOUN'}
           ]                                                                                                                                                                                  
m_tool.add('QBF', None, pattern,pattern1,pattern2,pattern3,pattern4,pattern5,pattern6,pattern7,
           pattern8,pattern9,pattern10,pattern11,pattern12,pattern13,pattern14,pattern15,
           pattern16,pattern17,pattern20,pattern21,pattern22)
sentence = nlp(text)   
phrase_matches = m_tool(sentence)
for match_id, start, end in phrase_matches:
    string_id = nlp.vocab.strings[match_id]  
    span = sentence[start:end]                   
    print(span.text)
# Out:
# Genetic algorithms and machine learning
# Machine-learning research
# Pattern recognition and machine learning
# Ensemble methods in machine learning
# Understanding machine learning: From theory to algorithms
# Correlation-based feature
# Data mining: practical machine learning tools and techniques with Java implementations
# Practical bayesian optimization of machine learning algorithms
# Can machine learning be secure?
# Thumbs up?: sentiment classification using machine learning techniques
# Kernel methods in machine learning
# Dataset shift in machine learning
# machine-learning supercomputer
# Graphical models for machine learning and digital communication
# Machine learning for user modeling
# Applications of machine learning and rule induction
# machine learning and rule induction
# Machine learning and data mining
# Machine learning and data mining
# Correlation-based feature
# Optimization methods for large-scale machine learning
# ...

# %%
pip install lexnlp
# Out:
# ...
#      |████████████████████████████████| 9.7MB 2.3MB/s
# ...
#      |████████████████████████████████| 22.6MB 1.7MB/s
# ...
#      |████████████████████████████████| 10.3MB 44.1MB/s
# ...
#      |████████████████████████████████| 61kB 9.6MB/s
# ...
#      |████████████████████████████████| 8.9MB 52.3MB/s
# ...
#      |████████████████████████████████| 50.0MB 65kB/s
# ...
#      |████████████████████████████████| 61kB 8.5MB/s
# ...
#      |████████████████████████████████| 102kB 14.5MB/s
# ...
#      |████████████████████████████████| 358kB 44.0MB/s
# ...
#      |████████████████████████████████| 614kB 44.3MB/s
# ...
#      |████████████████████████████████| 6.7MB 40.1MB/s
# ...
#      |████████████████████████████████| 235kB 32.8MB/s
# ...
#      |████████████████████████████████| 1.5MB 45.4MB/s
# ...
#      |████████████████████████████████| 133kB 49.2MB/s
# ...
#   Created wheel for us: filename=us-1.0.0-cp36-none-any.whl size=11833 sha256=4774d4e2630cccc1383ef1970ab315dfa5d6bd9ebd01a638c918ed1e5209c99f
# ...

# %%
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %% [markdown]
# **bold text**## **2. Domain-specific information extraction**
#
# For the legal case used in the data cleaning exercise: [01-05-1 Adams v Tanner.txt](https://raw.githubusercontent.com/unt-iialab/INFO5731_Spring2020/master/In_class_exercise/01-05-1%20%20Adams%20v%20Tanner.txt), use [legalNLP](https://lexpredict-lexnlp.readthedocs.io/en/latest/modules/extract/extract.html#nlp-based-extraction-methods) to extract the following inforation from the text (if the information is not exist, just print None):
#
# (1) acts, e.g., “section 1 of the Advancing Hope Act, 1986”
#
# (2) amounts, e.g., “ten pounds” or “5.8 megawatts”
#
# (3) citations, e.g., “10 U.S. 100” or “1998 S. Ct. 1”
#
# (4) companies, e.g., “Lexpredict LLC”
#
# (5) conditions, e.g., “subject to …” or “unless and until …”
#
# (6) constraints, e.g., “no more than”
#
# (7) copyright, e.g., “(C) Copyright 2000 Acme”
#
# (8) courts, e.g., “Supreme Court of New York”
#
# (9) CUSIP, e.g., “392690QT3”
#
# (10) dates, e.g., “June 1, 2017” or “2018-01-01”
#
# (11) definitions, e.g., “Term shall mean …”
#
# (12) distances, e.g., “fifteen miles”
#
# (13) durations, e.g., “ten years” or “thirty days”
#
# (14) geographic and geopolitical entities, e.g., “New York” or “Norway”
#
# (15) money and currency usages, e.g., “$5” or “10 Euro”
#
# (16) percents and rates, e.g., “10%” or “50 bps”
#
# (17) PII, e.g., “212-212-2121” or “999-999-9999”
#
# (18) ratios, e.g.,” 3:1” or “four to three”
#
# (19) regulations, e.g., “32 CFR 170”
#
# (20) trademarks, e.g., “MyApp (TM)”
#
# (21) URLs, e.g., “http://acme.com/”
#
# (22) addresses, e.g., “1999 Mount Read Blvd, Rochester, NY, USA, 14615”
#
# (23) persons, e.g., “John Doe

# %%
import pandas as pd
import csv

data = open('testfile.txt').read()
#collecting acts
import lexnlp.extract.en.acts
list1 = lexnlp.extract.en.acts.get_act_list(data)
if len(list1) == 0:
    print("None")
else: 
   print(list1)
#collecting amounts
import lexnlp.extract.en.amounts
print(list(lexnlp.extract.en.amounts.get_amounts(data)))
#collecting citations
import lexnlp.extract.en.citations
print(list(lexnlp.extract.en.citations.get_citations(data)))
# Out:
# None
# ...

# %%
#collecting companies
import lexnlp.extract.en.entities.nltk_re
print(list(lexnlp.extract.en.entities.nltk_re.get_companies(data)))
#collecting conditions
import lexnlp.extract.en.conditions
print(list(lexnlp.extract.en.conditions.get_conditions(data)))
#collecting constraints
import lexnlp.extract.en.constraints
print(list(lexnlp.extract.en.constraints.get_constraints(data)))
#collecting copyrights
import lexnlp.extract.en.copyright
print(list(lexnlp.extract.en.copyright.get_copyright(data)))
# Out:
# [Lehman, Durr Co, (17983, 18001)]
# ...

# %%
import lexnlp.extract.en.courts
text = "The case will be heard in E.D. Va. next month"
court_config_data = [entity_config(0, "Eastern District of Virginia", 0, ["E.D. Va."]),
    entity_config(1, "Western District of Virginia", 0, ["W.D. Va."])]
for entity, alias in lexnlp.extract.en.courts.get_courts(text, court_config_data):
    print("entity=", entity)
    print("alias=", alias)

# %%
#collecting geographic and geopolitical entities
import numpy as np
import pandas as pd
from urllib import request
from geotext import GeoText
from geopy.geocoders import Nominatim
from geopy.exc import GeocoderTimedOut
import descartes
geolocator = Nominatim(timeout=2)
geolocator = Nominatim()
lat_lon = []
for city in cities: 
    try:
        location = geolocator.geocode(city)
        if location:
            print(location.latitude, location.longitude)
            lat_lon.append(location)
    except GeocoderTimedOut as e:
        print("Error: geocode failed on input %s with message %s">(city, e))
lat_lon
# Out:
# /usr/local/lib/python3.6/dist-packages/geopy/geocoders/osm.py:143: UserWarning: Using Nominatim with the default "geopy/1.17.0" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
#   UserWarning
# 28.6689748 -82.076402
# 28.6689748 -82.076402
# 32.5233959 -94.3982158
# 32.5233959 -94.3982158
# 52.802742 -1.629917
# 32.5233959 -94.3982158
# 28.6689748 -82.076402
# 29.6519684 -82.3249846
# 29.6519684 -82.3249846
# 32.5233959 -94.3982158
# 32.5233959 -94.3982158
# 32.5233959 -94.3982158
# 32.5233959 -94.3982158
# 32.5233959 -94.3982158
# 30.2711286 -97.7436995
# 50.7179472 -1.981521
# 41.6021292 -87.3371372
# 42.4717601 140.8646839
# ...

# %%
#collecting cusips
import lexnlp.extract.en.cusip
print(lexnlp.extract.en.cusip.get_cusip(data))
#collecting dates
import lexnlp.extract.en.dates
print(list(lexnlp.extract.en.dates.get_dates(data)))
#collecting definitions
import lexnlp.extract.en.definitions
list2 = list(lexnlp.extract.en.definitions.get_definitions(data))
if len(list2) == 0:
    print("None")
else: 
   print(list2)
#collecting distances
import lexnlp.extract.en.distances
list3 = list(lexnlp.extract.en.distances.get_distances(data))
if len(list3) == 0:
    print("None")
else: 
   print(list3)
#collecting durations
import lexnlp.extract.en.durations
print(list(lexnlp.extract.en.durations.get_durations(data)))
#collecting money and currency usage
import lexnlp.extract.en.money
print(list(lexnlp.extract.en.money.get_money(data)))
#collecting percentages 
import lexnlp.extract.en.percents
list4 = list(lexnlp.extract.en.percents.get_percents(data))
if len(list4) == 0:
    print("None")
else: 
   print(list4)
#collecting PII
import lexnlp.extract.en.pii
list5 = list(lexnlp.extract.en.pii.get_pii(data))  
if len(list5) == 0:
    print("None")
else: 
   print(list5)
#collecting ratios
import lexnlp.extract.en.ratios
list6 = list(lexnlp.extract.en.ratios.get_ratios(data))  
if len(list6) == 0:
    print("None")
else: 
   print(list6)
#collecting regulations
import lexnlp.extract.en.regulations
list7 = list(lexnlp.extract.en.regulations.get_regulations(data))
if len(list7) == 0:
    print("None")
else: 
   print(list7)
#collecting trademarks   
import lexnlp.extract.en.trademarks
list8 = list(lexnlp.extract.en.trademarks.get_trademarks(data))
if len(list8) == 0:
    print("None")
else: 
   print(list8)
#collecting URL's
import lexnlp.extract.en.urls
list9 = list(lexnlp.extract.en.urls.get_urls(data))
if len(list9) == 0:
    print("None")
else: 
   print(list9)
# Out:
# <generator object get_cusip at 0x7f72735e0ca8>
# [datetime.date(2020, 6, 1), datetime.date(1840, 11, 1), datetime.date(1839, 10, 1), datetime.date(1840, 5, 1), datetime.date(1840, 9, 1), datetime.date(1840, 5, 1), datetime.date(1840, 5, 1), datetime.date(2020, 12, 1), datetime.date(2020, 12, 1), datetime.date(2020, 1, 1), datetime.date(2020, 1, 1), datetime.date(2020, 1, 1), datetime.date(2020, 3, 21), datetime.date(2020, 6, 1), datetime.date(2020, 7, 1), datetime.date(2020, 11, 1), datetime.date(1887, 5, 1)]
# None
# None
# [('second', 20.0, 0.00023148148148148146), ('year', 6.0, 2190.0)]
# [(100.0, 'USD'), (14000, 'USD'), (14000, 'USD')]
# None
# None
# None
# None
# None
# None

# %%
#extracting person names and address
import spacy
nlp = spacy.load("en_core_web_sm")
tagged_text = nlp(data)
extracted_entities = [(i.text, i.label_) for i in tagged_text.ents]
print(extracted_entities)
relevant_labels = ["PERSON"]
relevent_addresses = ["GPE"]

for relevant_label in relevant_labels:
    print("Extracted for label: " + relevant_label)
    for entity, label in extracted_entities:
        if label == relevant_label:
            print(entity)
for relevent_address in relevent_addresses:
    print("Extracted for label: " + relevent_address)
    for entity, label in extracted_entities:
        if label == relevent_address:
            print(entity)
# Out:
# [('5', 'CARDINAL'), ('Supreme Court of Alabama', 'ORG'), ('ADAMS', 'ORG'), ('TANNER', 'ORG'), ('HORTON', 'ORG'), ('Synopsis', 'GPE'), ('WRIT', 'PERSON'), ('Error', 'PERSON'), ('the Circuit Court of Sumter', 'ORG'), ('2', 'CARDINAL'), ('1', 'CARDINAL'), ('Chattel', 'ORG'), ('4', 'CARDINAL'), ('2', 'CARDINAL'), ('Lien', 'PERSON'), ('5', 'CARDINAL'), ('1', 'CARDINAL'), ('November, 1840', 'DATE'), ('Sumter', 'ORG'), ('Allen Harrison', 'PERSON'), ('thirty-seven hundred and seventy-seven', 'CARDINAL'), ('Allen Harrison', 'PERSON'), ('October, 1839', 'DATE'), ('741', 'CARDINAL'), ('7th', 'ORDINAL'), ('Harrison', 'GPE'), ('Harrison', 'GPE'), ('the twenty-second of May, 1840', 'DATE'), ('Burton & Harrison of Sumter county', 'ORG'), ('fourteen thousand dollars', 'MONEY'), ('one hundred and twenty acres', 'QUANTITY'), ('Allen Harrison', 'PERSON'), ('Gainesville', 'GPE'), ('Tennessee', 'GPE'), ('about the first of September, 1840', 'DATE'), ('three or four', 'CARDINAL'), ('Gainesville', 'GPE'), 
# ...
